# %%
import wave

def save_audio_file(audio_data, output_file):
    with wave.open(output_file, 'wb') as wf:
        wf.setnchannels(1)  # 设置为单声道
        wf.setsampwidth(2)  # 16位采样宽度（每个样本2个字节）
        wf.setframerate(16000)  # 设置采样率为16000 Hz
        wf.writeframes(audio_data)

# 示例使用
audio_data = b'\x00\x01\x02\x03\x04\x05\x06\x07\x08\x09'  # 替换为你的音频字节流字符串
output_file = 'output.wav'  # 输出文件名

save_audio_file(audio_data, output_file)

# %%
import requests
# dic = {
# "info":
# """ChatGPT4 is great,I love openAI !"""
# }

data = {
"click_once_count":
"4"
}

# for i in range(1):
#     url = 'http://192.168.43.247/info'
#     headers = {"Content-Type": "application/json"}
#     #dic["info"]=  " "*i+"""ChatGPT4 is great,I love openAI !"""
#     response = requests.post(url, json=data,headers= headers)
#     print(response)
#     #print(response.headers)
#     print(response.request.headers)

# url  ='http://192.168.43.247/showinfo'
# response = requests.get(url)
# print(response.json())

# for i in range(1):
#     r = requests.get("http://192.168.43.247/getinfo")
#     print(r.status_code)
#     print(r.text)




#input()

import requests
import base64
for i in range(5):
    # 打开图片文件，读取为字节流
    with open('a2.jpg', 'rb') as f:
        img_data = f.read()

    # 将字节流转换为Base64编码的字符串
    img_str = base64.b64encode(img_data)
    print(img_str)
    print(len(img_str))
    # 构造POST请求，发送图片字符串到ESP32的IP地址
    # url = 'http://192.168.43.247/upload_image'
    # data = {'image': img_str}
    # response = requests.post(url, data=data)

    # 输出ESP32的响应信息
    # print(response.text)


    #picture encoding base64 string post to esp32 webserver,
    #arduino esp32 use webserver to get base64 string ,decoded base64 string and use TFT_eSPI to show picture in tft lcd 



# encoding:utf-8
import matplotlib.pyplot as plt
import cv2
from io import BytesIO
import base64

# 二进制读取图片,再将图片转为 base64 类型的字符串
with open('a2.jpg', 'rb') as fin:   #第一个参数为图片全路径或相对路径
    print('二进制类型')
    image_data = fin.read()
    # 图片:二进制类型
    print(image_data)

    # 将二进制图片编码为 base64 格式
    print('二进制类型--转--bytes类型')
    base64_data_bytes = base64.b64encode(image_data)
    # 图片:bytes类型
    print(base64_data_bytes)

    # 在Python3以后，字符串和bytes类型彻底分开了。字符串是以字符为单位进行处理的，bytes类型是以字节为单位处理的。
    # 在 Python3 中，bytes和str的互相转换方式是
    # str.encode('utf-8')           bytes.decode('utf-8')

    print('bytes类型--转--str类型')
    base64_data_str= base64_data_bytes.decode()
    # 图片:str类型
    print(base64_data_str)
######################################################################
print('上面将图片转为字符串----下面再将此字符串转为图片')
print('通过打印str类型，再将其赋给一个变量，则这个变量就表示一张图片的str类型')
print('str类型表示会很长，可以用于pythonn使用PyInstalle库生成的exe文件中')
print('上面将图片转为字符串----下面再将此字符串转为图片')
######################################################################
print('str类型')
print(base64_data_str)

print('str类型--转--bytes类型')
base64_data_bytes = base64_data_str.encode('utf-8')
print(base64_data_bytes)

print('bytes类型--转--二进制类型')
image_data = base64.b64decode(base64_data_bytes)
print(image_data)

print('二进制类型--转--数组')
# 使用 matplotlib,io 库将二进制类型转为数组
img_data = plt.imread(BytesIO(image_data),"JPG")
#第一个参数目前还不清楚
# 第二个参数可以为 PNG、JPG
print(type(img_data))
print(img_data.shape)

# 使用cv2库显示图片
img_cv2 = cv2.cvtColor(img_data,cv2.COLOR_RGB2BGR)
cv2.imshow('a',img_cv2)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# b'...'
# 35108
# b'...'
# 35108
# b'...'
# 35108
# b'...'
# 35108
# b'...'
# 35108
# 二进制类型
# ...

# %%
import io
import base64
import scipy.io.wavfile as wavfile
b64_data = b''
# 模拟前端传来的base64解码为python二进制字符串
wav_bytes = base64.b64decode(b64_data)
print(wav_bytes)
# memory_wav = io.BytesIO(wav_bytes)
# rate, signal = wavfile.read(memory_wav)
# Out:
# b''

# %%
from io import BytesIO
from pydub import AudioSegment
import numpy as np
def save_audio_file(audio_data, output_file):
    audio_segment = AudioSegment.from_file(BytesIO(audio_data))
    audio_segment.export(output_file, format='mp3')

# 示例使用
audio_data = b'\x00\x01\x02\x03\x04\x05\x06\x07\x08\x09' # 替换为你的音频二进制流
data_float32 = np.frombuffer(audio_data, dtype=np.int8).astype(np.float32)
output_file = 'output.mp3'  # 输出文件名

save_audio_file(data_float32, output_file)
# Out:
# ---------------------------------------------------------------------------
# CouldntDecodeError                        Traceback (most recent call last)
# Untitled-1.ipynb Cell 4 in <cell line: 13>()
#      <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W2sdW50aXRsZWQ%3D?line=9'>10</a> data_float32 = np.frombuffer(audio_data, dtype=np.int8).astype(np.float32)
#      <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W2sdW50aXRsZWQ%3D?line=10'>11</a> output_file = 'output.mp3'  # 输出文件名
# ---> <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W2sdW50aXRsZWQ%3D?line=12'>13</a> save_audio_file(data_float32, output_file)
#
# Untitled-1.ipynb Cell 4 in save_audio_file(audio_data, output_file)
#       <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W2sdW50aXRsZWQ%3D?line=3'>4</a> def save_audio_file(audio_data, output_file):
# ...

# %%
import numpy as np
import soundfile as sf

# 示例数据，替换为你的实际数据
data_bytes = b''

sample_rate = 16000  # 采样率，单位Hz
output_file = '1output.wav'  # 输出文件名

# 将数据转换为float32类型
data_float32 = np.frombuffer(data_bytes, dtype=np.int8).astype(np.float32)
print(data_float32)
# 保存为音频文件
sf.write(output_file, data_float32, sample_rate)

print(f"音频文件保存成功：{output_file}")
# Out:
# [1. 0. 1. ... 0. 1. 0.]
# 音频文件保存成功：1output.wav

# %%
import numpy as np
import soundfile as sf

# 示例数据，替换为你的实际数据
data_bytes = b''

sample_rate = 16000  # 采样率，单位Hz
output_file = 'output.wav'  # 输出文件名

# 将数据转换为float32类型
data_float32 = np.frombuffer(data_bytes, dtype=np.int8).astype(np.float32)

# 保存为音频文件
sf.write(output_file, data_float32, sample_rate)

print(f"音频文件保存成功：{output_file}")
# Out:
# ---------------------------------------------------------------------------
# LibsndfileError                           Traceback (most recent call last)
# Untitled-1.ipynb Cell 6 in <cell line: 14>()
#      <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W5sdW50aXRsZWQ%3D?line=10'>11</a> data_float32 = np.frombuffer(data_bytes, dtype=np.int8).astype(np.float32)
#      <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W5sdW50aXRsZWQ%3D?line=12'>13</a> # 保存为音频文件
# ---> <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W5sdW50aXRsZWQ%3D?line=13'>14</a> sf.write(output_file, data_float32, sample_rate)
#      <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W5sdW50aXRsZWQ%3D?line=15'>16</a> print(f"音频文件保存成功：{output_file}")
#
# File c:\Users\vv\Miniconda3\lib\site-packages\soundfile.py:343, in write(file, data, samplerate, subtype, endian, format, closefd)
#     341 else:
#     342     channels = data.shape[1]
# ...

# %%
import numpy as np
import soundfile as sf
import matplotlib.pyplot as plt
# 示例数据，替换为你的实际数据
data_bytes = b''

sample_rate = 16000  # 采样率，单位Hz
output_file = '8output.wav'  # 输出文件名

# 将数据转换为float32类型并归一化范围
data_float32 = np.frombuffer(data_bytes, dtype=np.int8).astype(np.float32) 
print(data_float32>1)
data_float32 = np.maximum(data_float32,-1)
print(data_float32.shape)
# for i in range(100):
#     print(data_float32[i])
fg=plt.figure(1)
plt.plot(data_float32)
plt.show()

# 保存为音频文件，设置采样率和格式
sf.write(output_file, data_float32, sample_rate, format='WAV', subtype='PCM_16')

print(f"音频文件保存成功：{output_file}")
# Out:
# [False False False ... False False False]
# (1024,)
# 音频文件保存成功：8output.wav

# %%
import soundfile as sf
import matplotlib.pyplot as plt

wavsignal, rt = sf.read('hello.wav')
print(rt)
# for i in range(len(wavsignal)):
#     if wavsignal[i]>0:
#         print(wavsignal[i])
    

print(wavsignal.shape)
#print("sampling rate = {} Hz, length = {} samples, channels = {}".format(rt, *wavsignal.shape))
fg=plt.figure(1)
plt.plot(wavsignal)
plt.show()
# Out:
# 48000
# (210720,)

# %%
import soundfile as sf
import matplotlib.pyplot as plt

wavsignal, rt = sf.read('3050output.wav')
print(rt)
# for i in range(len(wavsignal)):
#     if wavsignal[i]>0:
#         print(wavsignal[i])
    

print(wavsignal.shape)
#print("sampling rate = {} Hz, length = {} samples, channels = {}".format(rt, *wavsignal.shape))
fg=plt.figure(1)
plt.plot(wavsignal)
plt.show()
# Out:
# 16000
# (25600,)
